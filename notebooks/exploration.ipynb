# %% [markdown]
# # Exploration rapide des données air quality
#
# Notebook minimal pour vérifier les colonnes et distributions du dataset utilisé pour simuler les capteurs IoT.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/air_quality_combined_source.csv')
print(df.shape)
df.head()

# %%
numeric_cols = ['PM2.5', 'PM10', 'NO2', 'SO2', 'CO', 'O3', 'temperature', 'humidity', 'wind_speed']
available = [c for c in numeric_cols if c in df.columns]
df[available].describe().T
